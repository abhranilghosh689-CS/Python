# %% [markdown]
# <a href="https://colab.research.google.com/github/abhranilghosh689-CS/Python/blob/main/Week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Day 1***

# %% [markdown]
# Word operations

# %%
# Print command
print("Hi! This is my 1st day as a Py noob.")
# Out:
# Hi! This is my 1st day as a Py noob.

# %%
# Using Esc commands
print("Hi! This is my 1st day as a Py noob. \n Let's learn.")
# Out:
# Hi! This is my 1st day as a Py noob.
#  Let's learn.

# %%
# Using Sep
print("Hey", 9, 6, sep ="~")
# Out:
# Hey~9~6

# %%
# Using end
print("Hi! This is my 1st day as a Py noob.", end="686")
print("\nWhat should I type?")
# Out:
# Hi! This is my 1st day as a Py noob.686
# What should I type?

# %% [markdown]
# Basic Math Problems

# %%
# Basic math problems
a = 63
b = 21
print("Add:", a + b)
print("Sub:", a - b)
print("Product:", a * b)
print("Divide:", a / b)
# Out:
# Add: 84
# Sub: 42
# Product: 1323
# Divide: 3.0

# %%
# Age Calculation
age = 17
print("Next year I will be", age + 1)
# Out:
# Next year I will be 18

# %% [markdown]
# ***Day 2***

# %%
# Variable Types 1
a = 9
b = True
c = "Child"
d = None
e = {}
print("The type of a is", type(a))
print("The type of b is", type(b))
print("The type of c is", type(c))
print("The type of d is", type(d))
print("The type of e is", type(e))
# Out:
# The type of a is <class 'int'>
# The type of b is <class 'bool'>
# The type of c is <class 'str'>
# The type of d is <class 'NoneType'>
# The type of e is <class 'dict'>

# %%
# Variable Types 2
list1 = [3, 4, [-9, 36], ["Apple","Banana"]]
print(list1)
dict1 = {"name" :"Anny", "age" :20}
print(dict1)
# Out:
# [3, 4, [-9, 36], ['Apple', 'Banana']]
# {'name': 'Anny', 'age': 20}

# %%
# Taking Inputs & Calculator construction
a, b = int(input("Enter value of a: ")), int(input("Enter value of b: "))
print("Add:", a + b)
print("Sub:", a - b)
print("Multiply:", a * b)
print("Division:", a / b)
print("Exponent:", a ** b)
print("Modulus:", a % b)
print("Floor Division:", a // b)
# Out:
# Enter value of a: 10
# Enter value of b: 5
# Add: 15
# Sub: 5
# Multiply: 50
# Division: 2.0
# Exponent: 100000
# Modulus: 0
# Floor Division: 2

# %% [markdown]
# ***Day 3***

# %%
# Strings
name = "Abhranil"
friend = "Ghosh"
print("Hello, "+ name)
print(name[0])
print(name[1])
print(name[2])
print(name[3])
print(name[4])
print(name[5])
print(name[6])
print(name[7])
print(" ")

# For Loop
for char in friend:
  print(char)
# Out:
# Hello, Abhranil
# A
# b
# h
# r
# a
# n
# i
# l
#
# G
# h
# o
# s
# h

# %% [markdown]
# ***Day 4***

# %%
# Area of Triangle
base = float(input("Enter base : "))
height = float(input("Enter height : "))
a1 = (base * height) / 2
print("Area of Triangle: ",a1)
# Out:
# Enter base : 65
# Enter height : 89
# Area of Triangle:  2892.5

# %%
# Area of Rectangle
length = float(input("Enter length : "))
width = float(input("Enter width : "))
a2 = length * width
print("Area of Rectangle: ",a2)
# Out:
# Enter length : 56
# Enter width : 25
# Area of Rectangle:  1400.0

# %%
# Area of Square
side = float(input("Enter side : "))
a3 = side ** 2
print("Area of Square: ",a3)
# Out:
# Enter side : 56
# Area of Square:  3136.0

# %%
# Area of Circle
rad = float(input("Enter radius : "))
import math
area = math.pi * rad ** 2
print(f"Area of Circle : {area:.2f}")
# Out:
# Enter radius : 56
# Area of Circle : 9852.03

# %% [markdown]
# ***Day 5***

# %%
# String Operations
fruit = "Avocado"
len1 = len(fruit)
print("Avocado is a", len1, "letter word.")
print(fruit[0:5])
print(fruit[2:6])
print(fruit[0:-3])
# Out:
# Avocado is a 7 letter word.
# Avoca
# ocad
# Avoc

# %%
a = "5NkufGo9J"
print(a.upper())
print(a.lower())
print(len(a))
b = "!!!!Ko6YBrty!!!!!!"
print(b.rstrip("!"))
print(b.endswith("!!!!!!"))
c = "Welcome to the Shop !!!"
print(c.replace("Shop", "Sun"))
# Out:
# 5NKUFGO9J
# 5nkufgo9j
# 9
# !!!!Ko6YBrty
# True
# Welcome to the Sun !!!

# %%
c = "!!Hyong !!jiko okasa"
print(c.split(" "))
d = "introduction to py"
print(d.capitalize()) # Capitalized i to I
e = "You're not welcomed"
print(e.center(150))
print(e.count("e"))
print(e.find("not"))
# Out:
# ['!!Hyong', '!!jiko', 'okasa']
# Introduction to py
#                                                                  You're not welcomed
# 3
# 7

# %%
str1 = "0Welcome9ToTheConsole0"
str2 = "Welcome8 To The Console3"
print(str1.isalnum())
print(str2.isalnum())
str3 = "Welcome8 To The Console3"
str4 = "WelcomeToTheConsole"
print(str3.isalpha())
print(str4.isalpha())
# Out:
# True
# False
# False
# True

# %%
Q = "What's Your Name"
L = "what's your name"
print(Q.islower())
print(L.islower())
a = "We wish you a Merry Christmas"
b = "We wish you a Merry Christmas\n"
print(a.isprintable())
print(b.isprintable())
# Out:
# False
# True
# True
# False

# %%
x = "    "    # Using Spacebar
y = "     "   # Using Tab
print(x.isspace())
print(y.isspace())
o = "My Cat Is Sleeping On My Lap"
g = "my cat is lazy"
print(o.istitle())
print(g.istitle())
print(o.startswith("My"))
# Out:
# True
# True
# True
# False
# True

# %%
l = "VIRUS"
p = "virus"
print(l.isupper())
print(p.isupper())
k = "Python is a High Level Language \nIt is also a Interpreted Language."
print(k.swapcase())
# Out:
# True
# False
# pYTHON IS A hIGH lEVEL lANGUAGE
# iT IS ALSO A iNTERPRETED lANGUAGE.

# %%
s = "his name is dan and he is an honest guy"
print(s.title())
# Out:
# His Name Is Dan And He Is An Honest Guy
