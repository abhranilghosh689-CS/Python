# %% [markdown]
# <a href="https://colab.research.google.com/github/abhranilghosh689-CS/Python/blob/main/Week_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Day 1***

# %%
t1 = ["Indonasia", "Thailand", "China", "South Korea", "Malaysia", "Japan"]
t2 = [6, 1, 6, 3, 6, 2, 3, 2, 3, 6]
res1 = t2.count(2)
print("Count of 2 in t2 is :", res1)
res2 = t2.index(2)
print("Index of 2 in t2 is :", res2)
# Out:
# Count of 2 in t2 is : 2
# Index of 2 in t2 is : 5

# %%
# KBC Game
def kbc_game():
    questions = [
        ["What is the capital of India?", "A. Mumbai", "B. Delhi", "C. Kolkata", "D. Chennai", "B"],
        ["Which planet is known as the Red Planet?", "A. Earth", "B. Venus", "C. Mars", "D. Jupiter", "C"],
        ["Who wrote 'Romeo and Juliet'?", "A. Shakespeare", "B. Dickens", "C. Austen", "D. Twain", "A"],
        ["What is 5 * 6?", "A. 11", "B. 30", "C. 56", "D. 20", "B"],
        ["Which is the largest ocean?", "A. Atlantic", "B. Indian", "C. Arctic", "D. Pacific", "D"]
    ]
    money = [1000, 5000, 10000, 50000, 100000]
    winnings = 0
    print(" Welcome to KBC Game! \n")
    for i in range(len(questions)):
        q = questions[i]
        print(f"\nQuestion for ₹{money[i]}:")
        print(q[0])
        print(q[1])
        print(q[2])
        print(q[3])
        print(q[4])
        answer = input("Enter your answer (A/B/C/D): ").upper()
        if answer == q[5]:
            print(" Correct answer!")
            winnings = money[i]
            print(f"You won ₹{winnings}")
        else:
            print(" Wrong answer!")
            print(f"Correct answer was {q[5]}")
            break
    print(f"\n Game Over! Total winnings: ₹{winnings}")
# Run the game
kbc_game()
# Out:
#  Welcome to KBC Game!
#
#
# Question for ₹1000:
# What is the capital of India?
# A. Mumbai
# B. Delhi
# C. Kolkata
# D. Chennai
# Enter your answer (A/B/C/D): b
#  Correct answer!
# You won ₹1000
#
# Question for ₹5000:
# Which planet is known as the Red Planet?
# A. Earth
# B. Venus
# C. Mars
# D. Jupiter
# Enter your answer (A/B/C/D): c
#  Correct answer!
# You won ₹5000
#
# Question for ₹10000:
# Who wrote 'Romeo and Juliet'?
# A. Shakespeare
# B. Dickens
# C. Austen
# D. Twain
# Enter your answer (A/B/C/D): a
#  Correct answer!
# You won ₹10000
#
# Question for ₹50000:
# What is 5 * 6?
# A. 11
# B. 30
# C. 56
# D. 20
# Enter your answer (A/B/C/D): b
#  Correct answer!
# You won ₹50000
#
# Question for ₹100000:
# Which is the largest ocean?
# A. Atlantic
# B. Indian
# C. Arctic
# D. Pacific
# Enter your answer (A/B/C/D): d
#  Correct answer!
# You won ₹100000
#
#  Game Over! Total winnings: ₹100000

# %% [markdown]
# **Day 2**

# %%
# F-Strings
l = "Hey my name is {} and I'm from {}"
n = "CS"
c = "India"
print(l.format(n, c)) # Or
print(f"Hey my name is {n} and I'm from {c}")

txt = "For only {price:.2f} dollars! "
print(txt.format(price = 89.3698))
# Out:
# Hey my name is CS and I'm from India
# Hey my name is CS and I'm from India
# For only 89.37 dollars!

# %%
# Docstrings(Only works if put right below function)
def square(n) :
  '''Takes a number n, returns the square of n''' # This is doc string
  print(n**2)
square(5)
print(square.__doc__)
# Out:
# 25
# Takes a number n, returns the square of n

# %%
# PEP 8
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ***Day 3***

# %%
# Recursion
def factorial(n) :
  if n == 0 or n == 1 :
    return 1
  else:
    return n * factorial(n - 1)
print(factorial(int(input("Enter n: "))))
# Out:
# Enter n: 5
# 120

# %%
# Fibonacci Series
def fibonacci(k) :
  if k == 0 :
    return 0
  elif k == 1 :
    return 1
  else :
    return fibonacci(k - 1) + fibonacci(k - 2)
print(fibonacci(int(input("Enter n: "))))
# Out:
# Enter n: 15
# 610

# %%
# Sets
s = {2, 4, 2, 9}
print(s)
info = {"Yue", 19, False, 5.9, 19}
print(info)
for l in info:
  print(l)
# Out:
# {9, 2, 4}
# {False, 19, 5.9, 'Yue'}
# False
# 19
# 5.9
# Yue

# %%
# Sets Operations
s1 = {1, 2, 5, 6}
s2 = {3, 6, 7}
print(s1.union(s2))
s1.update(s2)
print(s1, s2)
# Out:
# {1, 2, 3, 5, 6, 7}
# {1, 2, 3, 5, 6, 7} {3, 6, 7}

# %%
c1 = {"Tokyo", "Shanghai", "Chongqing", "Shenzhen"}
c2 = {"Tokyo", "Seoul", "Madrid", "Chongqing"}
c3 = c1.intersection_update(c2)
print(c1)
c4 = c1.difference(c2)
print(c3)
print(c1.isdisjoint(c2))
# Out:
# {'Chongqing', 'Tokyo'}
# None
# False
# False

# %%
c5 = {"Tokyo", "Madrid", "Berlin", "Delhi"}
c6 = {"Seoul", "Kabul"}
print(c5.issuperset(c6))
c7 = {"Seoul", "Madrid", "Kabul"}
print(c7.issuperset(c6))
print(c6.issubset(c7))
# Out:
# False
# True
# True

# %%
c5 = {"Tokyo", "Madrid", "Berlin", "Delhi"}
c5.add("Guangzhou")
print(c5)
c5.update(c6)
print(c5)
c5.discard("Tokyo")
print(c5)
# Out:
# {'Delhi', 'Guangzhou', 'Madrid', 'Tokyo', 'Berlin'}
# {'Seoul', 'Delhi', 'Guangzhou', 'Madrid', 'Tokyo', 'Berlin', 'Kabul'}
# {'Seoul', 'Delhi', 'Guangzhou', 'Madrid', 'Berlin', 'Kabul'}

# %%
c5 = {"Tokyo", "Madrid", "Berlin", "Delhi"}
c9 = c5.pop()
print(c9)
del c9
c10 = c5.clear()
print(c10)
# Out:
# Delhi
# None
